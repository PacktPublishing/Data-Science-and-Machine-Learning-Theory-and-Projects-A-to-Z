# %%
# !pip install stable-baselines3[extra]

# %%
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %%
env = gym.make('CartPole-v0')

# %%
episodes = 15
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score += reward
        
    print("Episode: {} Score: {}".format(episode, score))
    
env.close()
# Out:
# Episode: 1 Score: 10.0
# Episode: 2 Score: 21.0
# Episode: 3 Score: 17.0
# Episode: 4 Score: 14.0
# Episode: 5 Score: 33.0
# Episode: 6 Score: 23.0
# Episode: 7 Score: 17.0
# Episode: 8 Score: 31.0
# Episode: 9 Score: 11.0
# Episode: 10 Score: 29.0
# Episode: 11 Score: 19.0
# Episode: 12 Score: 13.0
# Episode: 13 Score: 14.0
# Episode: 14 Score: 17.0
# Episode: 15 Score: 16.0

# %%
env.action_space.sample()
# Out:
# 0

# %%
env.observation_space.sample()
# Out:
# array([-2.7210507e+00, -6.8796260e+37, -4.0603167e-01, -1.3303160e+38],
#       dtype=float32)

# %%
env = DummyVecEnv([lambda: env])
model = PPO('MlpPolicy', env, verbose=1)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000)
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 923  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 615          |
# |    iterations           | 2            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0075467112 |
# |    clip_fraction        | 0.0829       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.687       |
# |    explained_variance   | -0.00357     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.01         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0121      |
# |    value_loss           | 49.1         |
# ...

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# C:\Users\mg\anaconda3\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (200.0, 0.0)

# %%
env.close()

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0
    
    while not done:
        env.render()
        action, _ = model.predict(state)
        state, reward, done, info = env.step(action)
        score += reward
        
    print("Episode: {} Score: {}".format(episode, score))
    
env.close()
# Out:
# Episode: 1 Score: [200.]
# Episode: 2 Score: [200.]
# Episode: 3 Score: [200.]
# Episode: 4 Score: [200.]
# Episode: 5 Score: [193.]

# %%
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold

# %%
save_path = r"C:\Users\mg\Desktop\RL\StableBaseLines Cartpole Solution\best"

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=195, verbose=1)

eval_callback = EvalCallback(env, callback_on_new_best=stop_callback, eval_freq=10000, 
                            best_model_save_path= save_path, verbose=1)

# %%
model = PPO('MlpPolicy', env, verbose=1)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 1028 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 656         |
# |    iterations           | 2           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008062548 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | -0.00894    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.97        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0172     |
# |    value_loss           | 62.9        |
# ...

# %%
net_arch = [dict(pi=[64,64,64], vf=[64,64,64])]

# %%
model = PPO('MlpPolicy', env, verbose=1, policy_kwargs={'net_arch': net_arch})
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 839  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 540        |
# |    iterations           | 2          |
# |    time_elapsed         | 7          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.01303708 |
# |    clip_fraction        | 0.143      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.684     |
# |    explained_variance   | -0.00875   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.1        |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0198    |
# |    value_loss           | 37.3       |
# ----------------------------------------
# ...

# %%
from stable_baselines3 import DQN

# %%
nodel = DQN('MlpPolicy', env, verbose=1)
# Out:
# Using cpu device

# %%
nodel.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.971    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 3655     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 62       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.934    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 3097     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 139      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.879    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 2961     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 254      |
# ----------------------------------
# ...

# %%
evaluate_policy(nodel, env, n_eval_episodes=10, render=True)
# Out:
# (10.0, 1.1832159566199232)

# %%
env.close()
