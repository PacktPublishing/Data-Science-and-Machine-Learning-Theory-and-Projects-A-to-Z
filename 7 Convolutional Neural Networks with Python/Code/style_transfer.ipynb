# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_hub as hub

# %%
C = plt.imread(r'C:\Users\DeLL\Desktop\ML\CNN\Data\StyleTransfer\content.jpg')

# %%
plt.imshow(C)

# %%
S = plt.imread(r'C:\Users\DeLL\Desktop\ML\CNN\Data\StyleTransfer\style.jpg')

# %%
plt.imshow(S)

# %%
model = hub.load('https://tfhub.dev/google/magenta/arbitrary-image-stylization-v1-256/1')

# %%
R = model(tf.constant(np.asarray(C[np.newaxis,...],'float32')),tf.constant(np.asarray(S[np.newaxis,...],'float32')))[0]

# %%
type(R)
# Out:
# tensorflow.python.framework.ops.EagerTensor

# %%
R = np.array(R*255,dtype=np.uint8)

# %%
R.shape
# Out:
# (1, 580, 700, 3)

# %%
plt.imshow(R[0])
